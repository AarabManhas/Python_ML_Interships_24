# %%
import numpy as np
import pandas as pd

# %%
disc={
    "Name":["RAM","SHAM","CARRY","VANSHIKA","ADII"],
    "Roll no":[1,2,3,4,5],
    "Grades":["A","B","C","D","A"],
    "Emails":["ram@gmai;.com","sham@gmail.com","carr@gmail.com","van@gmail.com","adii@gmail.com"]
}

# %%
df = pd.DataFrame(disc)
df
# Out:
#        Name  Roll no Grades          Emails
# 0       RAM        1      A   ram@gmai;.com
# 1      SHAM        2      B  sham@gmail.com
# 2     CARRY        3      C  carr@gmail.com
# 3  VANSHIKA        4      D   van@gmail.com
# 4      ADII        5      A  adii@gmail.com

# %%
df.head(2)
# Out:
#    Name  Roll no Grades          Emails
# 0   RAM        1      A   ram@gmai;.com
# 1  SHAM        2      B  sham@gmail.com

# %%
df.tail(2)
# Out:
#        Name  Roll no Grades          Emails
# 3  VANSHIKA        4      D   van@gmail.com
# 4      ADII        5      A  adii@gmail.com

# %%
cus = pd.read_csv('Customer Table Level 1.csv')
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
type(cus)
# Out:
# pandas.core.frame.DataFrame

# %%
type(cus['CustomerID'])
# Out:
# pandas.core.series.Series

# %%
cus.index
# Out:
# RangeIndex(start=0, stop=91, step=1)

# %%
cus.columns
# Out:
# Index(['CustomerID', 'Company Name', 'Costumer Name', 'City', 'PostalCode',
#        'Country'],
#       dtype='object')

# %%
cus.to_numpy()
# Out:
# array([[1, 'Alfreds Futterkiste', 'Maria Anders', 'Berlin', 12209,
#         'Germany'],
#        [2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo',
#         'Mexico D.F.', 5021, 'Mexico'],
#        [3, 'Antonio Moreno Taqueria', 'Antonio Moreno', 'Mexico D.F.',
#         5023, 'Mexico'],
#        [4, 'Around the Horn', 'Thomas Hardy', 'London', 34626, 'UK'],
#        [5, 'Berglunds snabbkp', 'Christina Berglund', 'Lulea', 95822,
#         'Sweden'],
#        [6, 'Blauer See Delikatessen', 'Hanna Moos', 'Mannheim', 68306,
#         'Germany'],
#        [7, 'Blondel pere et fils', 'Frederique Citeaux', 'Strasbourg',
#         67000, 'France'],
#        [8, 'BOlido Comidas preparadas', 'Martin Sommer', 'Madrid', 28023,
#         'Spain'],
#        [9, 'Bon app', 'Laurence Lebihans', 'Marseille', 13008, 'France'],
#        [10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'Tsawassen',
#         254685, 'Canada'],
# ...

# %%
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
cus.T
# Out:
#                                 0                                   1   \
# CustomerID                       1                                   2
# Company Name   Alfreds Futterkiste  Ana Trujillo Emparedados y helados
# Costumer Name         Maria Anders                        Ana Trujillo
# City                        Berlin                         Mexico D.F.
# PostalCode                   12209                                5021
# Country                    Germany                              Mexico
#
#                                     2                3                   4   \
# CustomerID                           3                4                   5
# Company Name   Antonio Moreno Taqueria  Around the Horn   Berglunds snabbkp
# Costumer Name           Antonio Moreno     Thomas Hardy  Christina Berglund
# City                       Mexico D.F.           London               Lulea
# PostalCode                        5023            34626               95822
# ...

# %%
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
cus.drop(0)
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# 5            6             Blauer See Delikatessen          Hanna Moos
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 1   Mexico D.F.        5021   Mexico
# 2   Mexico D.F.        5023   Mexico
# ...

# %%
cus.drop(1)
# Out:
#     CustomerID             Company Name       Costumer Name         City  \
# 0            1      Alfreds Futterkiste        Maria Anders       Berlin
# 2            3  Antonio Moreno Taqueria      Antonio Moreno  Mexico D.F.
# 3            4          Around the Horn        Thomas Hardy       London
# 4            5        Berglunds snabbkp  Christina Berglund        Lulea
# 5            6  Blauer See Delikatessen          Hanna Moos     Mannheim
# ..         ...                      ...                 ...          ...
# 86          87           Wartian Herkku    Pirkko Koskitalo         Oulu
# 87          88   Wellington Importadora       Paula Parente      Resende
# 88          89     White Clover Markets      Karl Jablonski      Seattle
# 89          90              Wilman Kala     Matti Karttunen     Helsinki
# 90          91                   Wolski             Zbyszek        Walla
#
#     PostalCode  Country
# 0        12209  Germany
# 2         5023   Mexico
# ...

# %%
cus.loc[(48, 78), ('Company Name', 'Costumer Name')]
# Out:
#                     Company Name     Costumer Name
# 48  Magazzini Alimentari Riuniti  Giovanni Rovelli
# 78            Toms Spezialitaten     Karin Josephs

# %%
cus.loc[tuple((np.arange(48,78))),('Company Name','Costumer Name')]
# Out:
#                     Company Name        Costumer Name
# 48  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49                  Maison Dewey      Catherine Dewey
# 50                Mere Paillarde       Jean Fresniere
# 51        Morgenstern Gesundkost      Alexander Feuer
# 52                   North/South       Simon Crowther
# 53        Oceano Atlantico Ltda.       Yvonne Moncada
# 54        Old World Delicatessen        Rene Phillips
# 55            Ottilies Kaseladen  Henriette Pfalzheim
# 56             Paris specialites       Marie Bertrand
# 57     Pericles Comidas clasicas  Guillermo Fernandez
# 58              Piccolo und mehr          Georg Pipps
# 59       Princesa Isabel Vinhoss     Isabel de Castro
# 60                   Que Delicia     Bernardo Batista
# 61                 Queen Cozinha       Lucia Carvalho
# 62                    QUICK-Stop          Horst Kloss
# 63                 Rancho grande     Sergio Gutierrez
# ...

# %%
cus.loc[np.arange(48,78),:]
# Out:
#     CustomerID                  Company Name        Costumer Name  \
# 48          49  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49          50                  Maison Dewey      Catherine Dewey
# 50          51                Mere Paillarde       Jean Fresniere
# 51          52        Morgenstern Gesundkost      Alexander Feuer
# 52          53                   North/South       Simon Crowther
# 53          54        Oceano Atlantico Ltda.       Yvonne Moncada
# 54          55        Old World Delicatessen        Rene Phillips
# 55          56            Ottilies Kaseladen  Henriette Pfalzheim
# 56          57             Paris specialites       Marie Bertrand
# 57          58     Pericles Comidas clasicas  Guillermo Fernandez
# 58          59              Piccolo und mehr          Georg Pipps
# 59          60       Princesa Isabel Vinhoss     Isabel de Castro
# 60          61                   Que Delicia     Bernardo Batista
# ...

# %%
cus.loc[np.arange(48,78),('Company Name','Costumer Name')]
# Out:
#                     Company Name        Costumer Name
# 48  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49                  Maison Dewey      Catherine Dewey
# 50                Mere Paillarde       Jean Fresniere
# 51        Morgenstern Gesundkost      Alexander Feuer
# 52                   North/South       Simon Crowther
# 53        Oceano Atlantico Ltda.       Yvonne Moncada
# 54        Old World Delicatessen        Rene Phillips
# 55            Ottilies Kaseladen  Henriette Pfalzheim
# 56             Paris specialites       Marie Bertrand
# 57     Pericles Comidas clasicas  Guillermo Fernandez
# 58              Piccolo und mehr          Georg Pipps
# 59       Princesa Isabel Vinhoss     Isabel de Castro
# 60                   Que Delicia     Bernardo Batista
# 61                 Queen Cozinha       Lucia Carvalho
# 62                    QUICK-Stop          Horst Kloss
# 63                 Rancho grande     Sergio Gutierrez
# ...

# %%
cus.loc[:,'Company Name']
# Out:
# 0                    Alfreds Futterkiste
# 1     Ana Trujillo Emparedados y helados
# 2                Antonio Moreno Taqueria
# 3                        Around the Horn
# 4                      Berglunds snabbkp
#                      ...
# 86                        Wartian Herkku
# 87                Wellington Importadora
# 88                  White Clover Markets
# 89                           Wilman Kala
# 90                                Wolski
# Name: Company Name, Length: 91, dtype: object

# %%
# Sample data for the dictionary
data = [
    {"Company Name": "Company A", "Employee Name": "Alice Smith", "Position": "Software Engineer"},
    {"Company Name": "Company B", "Employee Name": "Bob Johnson", "Position": "Data Analyst"},
    {"Company Name": "Company C", "Employee Name": "Carol Williams", "Position": "Product Manager"},
    {"Company Name": "Company D", "Employee Name": "David Brown", "Position": "Designer"},
    {"Company Name": "Company E", "Employee Name": "Eve Davis", "Position": "Marketing Specialist"},
    # Add more entries up to 50
    {"Company Name": "Company F", "Employee Name": "Frank Miller", "Position": "HR Manager"},
    {"Company Name": "Company G", "Employee Name": "Grace Wilson", "Position": "Accountant"},
    {"Company Name": "Company H", "Employee Name": "Hank Moore", "Position": "Sales Executive"},
    {"Company Name": "Company I", "Employee Name": "Ivy Taylor", "Position": "Customer Support"},
    {"Company Name": "Company J", "Employee Name": "Jack Anderson", "Position": "Business Analyst"},
    {"Company Name": "Company K", "Employee Name": "Karen Thomas", "Position": "Financial Advisor"},
    {"Company Name": "Company L", "Employee Name": "Larry Jackson", "Position": "Software Developer"},
    {"Company Name": "Company M", "Employee Name": "Mia White", "Position": "Operations Manager"},
    {"Company Name": "Company N", "Employee Name": "Nate Harris", "Position": "Project Manager"},
    {"Company Name": "Company O", "Employee Name": "Olivia Martin", "Position": "UX/UI Designer"},
    {"Company Name": "Company P", "Employee Name": "Paul Lee", "Position": "Data Scientist"},
    {"Company Name": "Company Q", "Employee Name": "Quincy Young", "Position": "Network Engineer"},
    {"Company Name": "Company R", "Employee Name": "Rachel King", "Position": "HR Specialist"},
    {"Company Name": "Company S", "Employee Name": "Sam Walker", "Position": "Technical Writer"},
    {"Company Name": "Company T", "Employee Name": "Tina Hall", "Position": "Quality Assurance"},
    {"Company Name": "Company U", "Employee Name": "Uma Lewis", "Position": "Business Development"},
    {"Company Name": "Company V", "Employee Name": "Victor Scott", "Position": "Software Tester"},
    {"Company Name": "Company W", "Employee Name": "Wendy Green", "Position": "Social Media Manager"},
    {"Company Name": "Company X", "Employee Name": "Xander Adams", "Position": "Content Creator"},
    {"Company Name": "Company Y", "Employee Name": "Yara Nelson", "Position": "Systems Administrator"},
    {"Company Name": "Company Z", "Employee Name": "Zachary Baker", "Position": "IT Support"},
    {"Company Name": "Company AA", "Employee Name": "Amy Edwards", "Position": "Research Scientist"},
    {"Company Name": "Company BB", "Employee Name": "Brian Carter", "Position": "Logistics Coordinator"},
    {"Company Name": "Company CC", "Employee Name": "Clara Phillips", "Position": "Procurement Manager"},
    {"Company Name": "Company DD", "Employee Name": "Daniel Roberts", "Position": "Compliance Officer"},
    {"Company Name": "Company EE", "Employee Name": "Ella Martinez", "Position": "Training Specialist"},
    {"Company Name": "Company FF", "Employee Name": "Fred Thompson", "Position": "Legal Advisor"},
    {"Company Name": "Company GG", "Employee Name": "Gina Hernandez", "Position": "Corporate Strategist"},
    {"Company Name": "Company HH", "Employee Name": "Harry Clark", "Position": "Customer Success Manager"},
    {"Company Name": "Company II", "Employee Name": "Iris Rodriguez", "Position": "Executive Assistant"},
    {"Company Name": "Company JJ", "Employee Name": "Jason Lewis", "Position": "Operations Analyst"},
    {"Company Name": "Company KK", "Employee Name": "Kylie Lee", "Position": "Talent Acquisition Specialist"},
    {"Company Name": "Company LL", "Employee Name": "Leon Scott", "Position": "Digital Marketing Manager"},
    {"Company Name": "Company MM", "Employee Name": "Megan Allen", "Position": "Supply Chain Analyst"},
    {"Company Name": "Company NN", "Employee Name": "Nathan King", "Position": "Technical Support Engineer"},
    {"Company Name": "Company OO", "Employee Name": "Olga Baker", "Position": "Public Relations Specialist"},
    {"Company Name": "Company PP", "Employee Name": "Peter White", "Position": "Business Consultant"},
    {"Company Name": "Company QQ", "Employee Name": "Quinn Foster", "Position": "Web Developer"},
    {"Company Name": "Company RR", "Employee Name": "Rita Nelson", "Position": "Database Administrator"},
    {"Company Name": "Company SS", "Employee Name": "Steve Johnson", "Position": "IT Manager"},
    {"Company Name": "Company TT", "Employee Name": "Tina Edwards", "Position": "Sales Manager"},
    {"Company Name": "Company UU", "Employee Name": "Umar Brown", "Position": "Investment Analyst"},
    {"Company Name": "Company VV", "Employee Name": "Vera Wilson", "Position": "Chief Technology Officer"},
    {"Company Name": "Company WW", "Employee Name": "Wade Harris", "Position": "Chief Financial Officer"},
    {"Company Name": "Company XX", "Employee Name": "Xena Martinez", "Position": "Chief Executive Officer"},
    {"Company Name": "Company YY", "Employee Name": "Yusuf Robinson", "Position": "Chief Operations Officer"},
    {"Company Name": "Company ZZ", "Employee Name": "Zoe Parker", "Position": "Chief Marketing Officer"}
]

# Convert list of dictionaries to a dictionary with indices as keys
dictionary = {i: entry for i, entry in enumerate(data)}

# Print the dictionary
for key, value in dictionary.items():
    print(f"{key}: {value}")
# Out:
# 0: {'Company Name': 'Company A', 'Employee Name': 'Alice Smith', 'Position': 'Software Engineer'}
# 1: {'Company Name': 'Company B', 'Employee Name': 'Bob Johnson', 'Position': 'Data Analyst'}
# 2: {'Company Name': 'Company C', 'Employee Name': 'Carol Williams', 'Position': 'Product Manager'}
# 3: {'Company Name': 'Company D', 'Employee Name': 'David Brown', 'Position': 'Designer'}
# 4: {'Company Name': 'Company E', 'Employee Name': 'Eve Davis', 'Position': 'Marketing Specialist'}
# 5: {'Company Name': 'Company F', 'Employee Name': 'Frank Miller', 'Position': 'HR Manager'}
# 6: {'Company Name': 'Company G', 'Employee Name': 'Grace Wilson', 'Position': 'Accountant'}
# 7: {'Company Name': 'Company H', 'Employee Name': 'Hank Moore', 'Position': 'Sales Executive'}
# 8: {'Company Name': 'Company I', 'Employee Name': 'Ivy Taylor', 'Position': 'Customer Support'}
# 9: {'Company Name': 'Company J', 'Employee Name': 'Jack Anderson', 'Position': 'Business Analyst'}
# ...

# %%
df=pd.DataFrame(dictionary)
df
# Out:
#                               0             1                2            3   \
# Company Name           Company A     Company B        Company C    Company D
# Employee Name        Alice Smith   Bob Johnson   Carol Williams  David Brown
# Position       Software Engineer  Data Analyst  Product Manager     Designer
#
#                                  4             5             6   \
# Company Name              Company E     Company F     Company G
# Employee Name             Eve Davis  Frank Miller  Grace Wilson
# Position       Marketing Specialist    HR Manager    Accountant
#
#                             7                 8                 9   ...  \
# Company Name         Company H         Company I         Company J  ...
# Employee Name       Hank Moore        Ivy Taylor     Jack Anderson  ...
# Position       Sales Executive  Customer Support  Business Analyst  ...
#
#                           42                      43             44  \
# ...

# %%
cd=pd.DataFrame(dictionary)
cd
# Out:
#                               0             1                2            3   \
# Company Name           Company A     Company B        Company C    Company D
# Employee Name        Alice Smith   Bob Johnson   Carol Williams  David Brown
# Position       Software Engineer  Data Analyst  Product Manager     Designer
#
#                                  4             5             6   \
# Company Name              Company E     Company F     Company G
# Employee Name             Eve Davis  Frank Miller  Grace Wilson
# Position       Marketing Specialist    HR Manager    Accountant
#
#                             7                 8                 9   ...  \
# Company Name         Company H         Company I         Company J  ...
# Employee Name       Hank Moore        Ivy Taylor     Jack Anderson  ...
# Position       Sales Executive  Customer Support  Business Analyst  ...
#
#                           42                      43             44  \
# ...

# %%
cd=cd.T

# %%
cd
# Out:
#    Company Name   Employee Name                       Position
# 0     Company A     Alice Smith              Software Engineer
# 1     Company B     Bob Johnson                   Data Analyst
# 2     Company C  Carol Williams                Product Manager
# 3     Company D     David Brown                       Designer
# 4     Company E       Eve Davis           Marketing Specialist
# 5     Company F    Frank Miller                     HR Manager
# 6     Company G    Grace Wilson                     Accountant
# 7     Company H      Hank Moore                Sales Executive
# 8     Company I      Ivy Taylor               Customer Support
# 9     Company J   Jack Anderson               Business Analyst
# 10    Company K    Karen Thomas              Financial Advisor
# 11    Company L   Larry Jackson             Software Developer
# 12    Company M       Mia White             Operations Manager
# 13    Company N     Nate Harris                Project Manager
# ...

# %%
cd.drop_duplicates(subset='Company Name',keep=False)
# Out:
#    Company Name   Employee Name                       Position
# 0     Company A     Alice Smith              Software Engineer
# 1     Company B     Bob Johnson                   Data Analyst
# 2     Company C  Carol Williams                Product Manager
# 3     Company D     David Brown                       Designer
# 4     Company E       Eve Davis           Marketing Specialist
# 5     Company F    Frank Miller                     HR Manager
# 6     Company G    Grace Wilson                     Accountant
# 7     Company H      Hank Moore                Sales Executive
# 8     Company I      Ivy Taylor               Customer Support
# 9     Company J   Jack Anderson               Business Analyst
# 10    Company K    Karen Thomas              Financial Advisor
# 11    Company L   Larry Jackson             Software Developer
# 12    Company M       Mia White             Operations Manager
# 13    Company N     Nate Harris                Project Manager
# ...

# %%
xlrd and openpyxl are the libraries to handel excel files in pandas

# %%
com_dat=pd.read_csv('company data.csv')
com_dat
# Out:
#                    0             1                2            3  \
# 0          Company A     Company B        Company C    Company D
# 1        Alice Smith   Bob Johnson   Carol Williams  David Brown
# 2  Software Engineer  Data Analyst  Product Manager     Designer
#
#                       4             5             6                7  \
# 0             Company E     Company F     Company G        Company H
# 1             Eve Davis  Frank Miller  Grace Wilson       Hank Moore
# 2  Marketing Specialist    HR Manager    Accountant  Sales Executive
#
#                   8                 9  ...             42  \
# 0         Company I         Company J  ...     Company QQ
# 1        Ivy Taylor     Jack Anderson  ...   Quinn Foster
# 2  Customer Support  Business Analyst  ...  Web Developer
#
#                        43             44             45                  46  \
# 0              Company RR     Company SS     Company TT          Company UU
# ...

# %%
com_dat.drop(2,axis=0)
# Out:
#              0            1               2            3          4  \
# 0    Company A    Company B       Company C    Company D  Company E
# 1  Alice Smith  Bob Johnson  Carol Williams  David Brown  Eve Davis
#
#               5             6           7           8              9  ...  \
# 0     Company F     Company G   Company H   Company I      Company J  ...
# 1  Frank Miller  Grace Wilson  Hank Moore  Ivy Taylor  Jack Anderson  ...
#
#              42           43             44            45          46  \
# 0    Company QQ   Company RR     Company SS    Company TT  Company UU
# 1  Quinn Foster  Rita Nelson  Steve Johnson  Tina Edwards  Umar Brown
#
#             47           48             49              50          51
# 0   Company VV   Company WW     Company XX      Company YY  Company ZZ
# 1  Vera Wilson  Wade Harris  Xena Martinez  Yusuf Robinson  Zoe Parker
#
# [2 rows x 52 columns]

# %%
com_dat
# Out:
#                    0             1                2            3  \
# 0          Company A     Company B        Company C    Company D
# 1        Alice Smith   Bob Johnson   Carol Williams  David Brown
# 2  Software Engineer  Data Analyst  Product Manager     Designer
#
#                       4             5             6                7  \
# 0             Company E     Company F     Company G        Company H
# 1             Eve Davis  Frank Miller  Grace Wilson       Hank Moore
# 2  Marketing Specialist    HR Manager    Accountant  Sales Executive
#
#                   8                 9  ...             42  \
# 0         Company I         Company J  ...     Company QQ
# 1        Ivy Taylor     Jack Anderson  ...   Quinn Foster
# 2  Customer Support  Business Analyst  ...  Web Developer
#
#                        43             44             45                  46  \
# 0              Company RR     Company SS     Company TT          Company UU
# ...

# %%
com_dat.drop(2,axis=0,inplace=True)

# %%
com_dat
# Out:
#              0            1               2            3          4  \
# 0    Company A    Company B       Company C    Company D  Company E
# 1  Alice Smith  Bob Johnson  Carol Williams  David Brown  Eve Davis
#
#               5             6           7           8              9  ...  \
# 0     Company F     Company G   Company H   Company I      Company J  ...
# 1  Frank Miller  Grace Wilson  Hank Moore  Ivy Taylor  Jack Anderson  ...
#
#              42           43             44            45          46  \
# 0    Company QQ   Company RR     Company SS    Company TT  Company UU
# 1  Quinn Foster  Rita Nelson  Steve Johnson  Tina Edwards  Umar Brown
#
#             47           48             49              50          51
# 0   Company VV   Company WW     Company XX      Company YY  Company ZZ
# 1  Vera Wilson  Wade Harris  Xena Martinez  Yusuf Robinson  Zoe Parker
#
# [2 rows x 52 columns]

# %%
# Assuming com_dat has only 3 rows
indices_to_drop = [0] 
com_dat.drop(indices_to_drop, axis=0, inplace=True)

# %%
com_dat
# Out:
#              0            1               2            3          4  \
# 1  Alice Smith  Bob Johnson  Carol Williams  David Brown  Eve Davis
#
#               5             6           7           8              9  ...  \
# 1  Frank Miller  Grace Wilson  Hank Moore  Ivy Taylor  Jack Anderson  ...
#
#              42           43             44            45          46  \
# 1  Quinn Foster  Rita Nelson  Steve Johnson  Tina Edwards  Umar Brown
#
#             47           48             49              50          51
# 1  Vera Wilson  Wade Harris  Xena Martinez  Yusuf Robinson  Zoe Parker
#
# [1 rows x 52 columns]

# %%
com_dat.reset_index(drop=True,inplace=True)

# %%
com_dat
# Out:
#              0            1               2            3          4  \
# 0  Alice Smith  Bob Johnson  Carol Williams  David Brown  Eve Davis
#
#               5             6           7           8              9  ...  \
# 0  Frank Miller  Grace Wilson  Hank Moore  Ivy Taylor  Jack Anderson  ...
#
#              42           43             44            45          46  \
# 0  Quinn Foster  Rita Nelson  Steve Johnson  Tina Edwards  Umar Brown
#
#             47           48             49              50          51
# 0  Vera Wilson  Wade Harris  Xena Martinez  Yusuf Robinson  Zoe Parker
#
# [1 rows x 52 columns]
